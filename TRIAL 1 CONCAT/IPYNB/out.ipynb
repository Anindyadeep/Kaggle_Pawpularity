# %%
import json 
import matplotlib.pyplot as plt

# %%
history_json = open("/home/anindya/Documents/kaggle/Pawpularity/TRIAL 1 CONCAT/history.json", "r")
history = json.load(history_json)

# %%
plt.plot(history['train_loss'])
